# %%
base_path=f"abfss://sourcedata@storageforassessment.dfs.core.windows.net"
bronze_path=f"{base_path}/bronze/raw"
silver_path = f"{base_path}/silver"
gold_path= f"{silver_path}/gold"
catalog_name="abn_demo"


spark.sql(f"""
    CREATE SCHEMA IF NOT EXISTS bronze_abn
    LOCATION '{base_path}/bronze'
""")

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.bronze_abn.shows
    USING DELTA
    LOCATION '{bronze_path}/table/table_shows'
""")

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.bronze_abn.episodes
    USING DELTA
    LOCATION '{bronze_path}/table/table_episodes'
""")

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.bronze_abn.cast
    USING DELTA
    LOCATION '{bronze_path}/table/table_cast'
""")


spark.sql(f"""
    CREATE SCHEMA IF NOT EXISTS silver_abn
    LOCATION '{base_path}/silver'
""")

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.silver_abn.shows
    USING DELTA
    LOCATION '{silver_path}/table/table_shows'
""")

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.silver_abn.episodes
    USING DELTA
    LOCATION '{silver_path}/table/table_episodes'
""")

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.silver_abn.cast
    USING DELTA
    LOCATION '{silver_path}/table/table_cast'
""")

# COMMAND ----------

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.silver_abn.fact_table
    USING DELTA
    LOCATION '{silver_path}/table/fact'
""")



spark.sql(f"""
    CREATE SCHEMA IF NOT EXISTS gold_abn
    LOCATION '{base_path}/Gold'
""")


spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.gold_abn.episodes_per_season
    USING DELTA
    LOCATION '{gold_path}/table/episodes_per_season'
""")

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.gold_abn.avg_runtime
    USING DELTA
    LOCATION '{gold_path}/table/avg_runtime'
""")

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.gold_abn.top_cast
    USING DELTA
    LOCATION '{gold_path}/table/top_cast'
""")
spark.sql(f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.gold_abn.common_genres
    USING DELTA
    LOCATION '{gold_path}/table/common_genres'
""")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5301050309606108>, line 13
#       5 catalog_name="abn_demo"
#       8 spark.sql(f"""
#       9     CREATE SCHEMA IF NOT EXISTS bronze_abn
#      10     LOCATION '{base_path}/bronze'
#      11 """)
# ---> 13 spark.sql(f"""
#      14     CREATE TABLE IF NOT EXISTS {catalog_name}.bronze_abn.shows
#      15     USING DELTA
#      16     LOCATION '{bronze_path}/table/table_shows'
#      17 """)
#      19 spark.sql(f"""
#      20     CREATE TABLE IF NOT EXISTS {catalog_name}.bronze_abn.episodes
#      21     USING DELTA
#      22     LOCATION '{bronze_path}/table/table_episodes'
#      23 """)
#      25 spark.sql(f"""
#      26     CREATE TABLE IF NOT EXISTS {catalog_name}.bronze_abn.cast
#      27     USING DELTA
#      28     LOCATION '{bronze_path}/table/table_cast'
#      29 """)
#
# ...
