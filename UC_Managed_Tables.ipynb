# %%
# %sql
-- ================================
-- 1. CONFIGURATION
-- ================================
USE CATALOG abn_demo;

-- ================================
-- 2. BRONZE LAYER
-- ================================
CREATE SCHEMA IF NOT EXISTS abn_demo.bronze_abn;

CREATE TABLE IF NOT EXISTS abn_demo.bronze_abn.episodes
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/bronze/episodes';

CREATE TABLE IF NOT EXISTS abn_demo.bronze_abn.cast
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/bronze/cast';

-- ================================
-- 3. SILVER LAYER
-- ================================
CREATE SCHEMA IF NOT EXISTS abn_demo.silver_abn;

CREATE TABLE IF NOT EXISTS abn_demo.silver_abn.shows
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/silver/shows';

CREATE TABLE IF NOT EXISTS abn_demo.silver_abn.episodes
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/silver/episodes';

CREATE TABLE IF NOT EXISTS abn_demo.silver_abn.cast
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/silver/cast';

CREATE TABLE IF NOT EXISTS abn_demo.silver_abn.fact_table
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/silver/fact_table';

-- ================================
-- 4. GOLD LAYER
-- ================================
CREATE SCHEMA IF NOT EXISTS abn_demo.gold_abn;

CREATE TABLE IF NOT EXISTS abn_demo.gold_abn.episodes_per_season
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/gold/episodes_per_season';

CREATE TABLE IF NOT EXISTS abn_demo.gold_abn.avg_runtime
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/gold/avg_runtime';

CREATE TABLE IF NOT EXISTS abn_demo.gold_abn.top_cast
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/gold/top_cast';

CREATE TABLE IF NOT EXISTS abn_demo.gold_abn.common_genres
USING DELTA
LOCATION 'abfss://sourcedata@<storage-account>.dfs.core.windows.net/gold/common_genres';
